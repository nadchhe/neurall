# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_file_path = '/content/drive/MyDrive/ResNet_model.zip'
destination_directory = '/content/ResNet_model_extracted'

# !unzip {zip_file_path} -d {destination_directory}
# Out:
# Archive:  /content/drive/MyDrive/ResNet_model.zip
#   inflating: /content/ResNet_model_extracted/ResNet_model (1).h5

# %%
# !wget -O DenseNet_model.h5 "https://github.com/nadchhe/neurall/raw/refs/heads/main/DenseNet_model.h5"
# !wget -O Xception_model.h5 "https://github.com/nadchhe/neurall/raw/refs/heads/main/Xception_model.h5"
# Out:
# --2024-12-09 16:32:59--  https://github.com/nadchhe/neurall/raw/refs/heads/main/DenseNet_model.h5
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/nadchhe/neurall/refs/heads/main/DenseNet_model.h5 [following]
# --2024-12-09 16:32:59--  https://raw.githubusercontent.com/nadchhe/neurall/refs/heads/main/DenseNet_model.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35787696 (34M) [application/octet-stream]
# Saving to: ‘DenseNet_model.h5’
#
# DenseNet_model.h5   100%[===================>]  34.13M  --.-KB/s    in 0.1s
#
# 2024-12-09 16:33:01 (232 MB/s) - ‘DenseNet_model.h5’ saved [35787696/35787696]
#
# --2024-12-09 16:33:01--  https://github.com/nadchhe/neurall/raw/refs/heads/main/Xception_model.h5
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/nadchhe/neurall/refs/heads/main/Xception_model.h5 [following]
# --2024-12-09 16:33:02--  https://raw.githubusercontent.com/nadchhe/neurall/refs/heads/main/Xception_model.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 96507096 (92M) [application/octet-stream]
# Saving to: ‘Xception_model.h5’
#
# Xception_model.h5   100%[===================>]  92.04M   281MB/s    in 0.3s
#
# 2024-12-09 16:33:05 (281 MB/s) - ‘Xception_model.h5’ saved [96507096/96507096]

# %%
# !pip install kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d abhishek14398/gesture-recognition-dataset
# !unzip gesture-recognition-dataset.zip -d gesture_recognition_dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00029.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00031.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00033.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00035.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00037.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00039.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00041.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00043.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00045.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00047.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00049.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00051.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00053.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00055.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00057.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00059.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00061.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00063.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_08_Pro_Thumbs_Down_new/WIN_20180926_17_33_08_Pro_00065.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00013.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00014.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00015.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00016.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00017.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00018.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00019.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00020.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00021.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00022.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00023.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00024.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00025.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00026.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00027.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00028.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00029.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00030.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00031.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00032.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00033.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00034.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00035.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00036.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00037.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00038.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00039.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00040.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00041.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_09_Pro_Thumbs_Up_new/WIN_20180926_17_33_09_Pro_00042.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00012.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00014.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00016.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00018.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00020.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00022.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00024.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00026.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00028.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00030.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00032.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00034.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00036.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00038.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00040.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00042.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00044.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00046.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00048.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00050.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00052.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00054.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00056.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00058.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00060.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00062.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00064.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00066.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00068.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_46_Pro_Left_Swipe_new/WIN_20180926_17_33_46_Pro_00070.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00000.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00002.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00004.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00006.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00008.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00010.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00012.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00014.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00016.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00018.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00020.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00022.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00024.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00026.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00028.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00030.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00032.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00034.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00036.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00038.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00040.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00042.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00044.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00046.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00048.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00050.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00052.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00054.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00056.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Down_new/WIN_20180926_17_33_51_Pro_00058.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00002.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00004.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00006.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00008.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00010.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00012.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00014.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00016.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00018.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00020.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00022.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00024.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00026.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00028.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00030.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00032.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00034.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00036.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00038.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00040.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00042.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00044.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00046.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00048.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00050.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00052.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00054.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00056.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00058.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_33_51_Pro_Thumbs_Up_new/WIN_20180926_17_33_51_Pro_00060.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00004.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00006.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00008.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00010.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00012.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00014.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00016.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00018.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00020.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00022.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00024.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00026.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00028.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00030.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00032.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00034.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00036.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00038.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00040.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00042.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00044.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00046.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00048.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00050.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00052.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00054.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00056.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00058.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00060.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_34_37_Pro_Stop_new/WIN_20180926_17_34_37_Pro_00062.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00001.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00003.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00005.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00007.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00009.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00011.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00013.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00015.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00017.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00019.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00021.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00023.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00025.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00027.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00029.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00031.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00033.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00035.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00037.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00039.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00041.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00043.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00045.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00047.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00049.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00051.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00053.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00055.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00057.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_12_Pro_Thumbs_Down_new/WIN_20180926_17_35_12_Pro_00059.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00004.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00006.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00008.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00010.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00012.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00014.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00016.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00018.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00020.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00022.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00024.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00026.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00028.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00030.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00032.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00034.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00036.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00038.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00040.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00042.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00044.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00046.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00048.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00050.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00052.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00054.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00056.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00058.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00060.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_17_Pro_Stop_new/WIN_20180926_17_35_17_Pro_00062.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00015.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00016.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00017.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00018.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00019.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00020.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00021.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00022.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00023.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00024.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00025.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00026.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00027.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00028.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00029.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00030.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00031.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00032.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00033.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00034.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00035.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00036.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00037.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00038.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00039.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00040.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00041.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00042.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00043.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_35_Pro_Thumbs_Down_new/WIN_20180926_17_35_35_Pro_00044.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00006.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00008.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00010.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00012.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00014.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00016.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00018.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00020.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00022.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00024.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00026.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00028.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00030.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00032.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00034.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00036.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00038.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00040.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00042.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00044.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00046.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00048.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00050.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00052.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00054.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00056.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00058.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00060.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00062.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_35_54_Pro_Thumbs_Up_new/WIN_20180926_17_35_54_Pro_00064.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00003.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00005.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00007.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00009.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00011.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00013.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00015.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00017.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00019.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00021.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00023.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00025.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00027.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00029.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00031.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00033.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00035.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00037.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00039.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00041.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00043.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00045.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00047.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00049.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00051.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00053.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00055.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00057.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00059.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_08_Pro_Thumbs_Down_new/WIN_20180926_17_36_08_Pro_00061.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00005.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00007.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00009.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00011.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00013.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00015.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00017.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00019.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00021.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00023.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00025.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00027.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00029.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00031.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00033.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00035.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00037.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00039.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00041.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00043.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00045.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00047.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00049.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00051.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00053.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00055.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00057.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00059.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00061.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_31_Pro_Thumbs_Down_new/WIN_20180926_17_36_31_Pro_00063.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00013.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00015.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00017.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00019.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00021.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00023.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00025.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00027.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00029.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00031.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00033.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00035.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00037.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00039.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00041.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00043.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00045.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00047.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00049.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00051.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00053.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00055.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00057.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00059.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00061.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00063.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00065.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00067.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00069.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_36_34_Pro_Right_Swipe_new/WIN_20180926_17_36_34_Pro_00071.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00001.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00003.png
#   inflating: gesture_recognition_dataset/train/WIN_20180926_17_37_02_Pro_Stop_new/WIN_20180926_17_37_02_Pro_00005.png
# ...
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00048.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00050.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00052.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00054.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00056.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00058.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00060.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_34_23_Pro_Thumbs_Down_new/WIN_20180926_17_34_23_Pro_00062.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00007.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00009.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00011.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00013.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00015.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00017.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00019.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00021.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00023.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00025.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00027.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00029.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00031.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00033.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00035.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00037.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00039.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00041.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00043.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00045.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00047.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00049.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00051.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00053.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00055.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00057.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00059.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00061.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00063.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_35_34_Pro_Right_Swipe_new/WIN_20180926_17_35_34_Pro_00065.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00009.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00011.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00013.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00015.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00017.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00019.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00021.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00023.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00025.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00027.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00029.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00031.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00033.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00035.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00037.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00039.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00041.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00043.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00045.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00047.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00049.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00051.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00053.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00055.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00057.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00059.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00061.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00063.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00065.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_40_21_Pro_Left_Swipe_new/WIN_20180926_17_40_21_Pro_00067.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00001.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00003.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00005.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00007.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00009.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00011.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00013.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00015.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00017.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00019.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00021.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00023.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00025.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00027.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00029.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00031.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00033.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00035.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00037.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00039.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00041.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00043.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00045.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00047.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00049.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00051.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00053.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00055.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00057.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_44_14_Pro_Thumbs_Down_new/WIN_20180926_17_44_14_Pro_00059.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00009.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00011.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00013.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00015.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00017.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00019.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00021.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00023.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00025.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00027.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00029.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00031.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00033.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00035.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00037.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00039.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00041.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00043.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00045.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00047.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00049.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00051.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00053.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00055.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00057.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00059.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00061.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00063.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00065.png
#   inflating: gesture_recognition_dataset/val/WIN_20180926_17_56_52_Pro_Right_Swipe_new/WIN_20180926_17_56_52_Pro_00067.png

# %%
# !pip install tensorflow
# !pip install keras
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.13.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
# Import libraries
import tensorflow as tf
from tensorflow.keras.applications import Xception, DenseNet121
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Conv2D, MaxPooling2D, BatchNormalization, Dropout, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os

# %%
# Paths for dataset
dataset_path = "gesture_recognition_dataset"  # Update with your dataset path
img_size = (224, 224)  # Image dimensions
batch_size = 32

# Image Data Generators
datagen = ImageDataGenerator(
    rescale=1.0 / 255,  # Normalize images
    validation_split=0.2,  # Split for validation
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

train_gen = datagen.flow_from_directory(
    dataset_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

val_gen = datagen.flow_from_directory(
    dataset_path,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 18312 images belonging to 2 classes.
# Found 4578 images belonging to 2 classes.

# %%
#RESNET
def build_resnet_from_scratch(input_shape, num_classes):
    model = Sequential([
        Input(shape=input_shape),
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        BatchNormalization(),

        Conv2D(128, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        BatchNormalization(),

        Conv2D(256, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),
        BatchNormalization(),

        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    return model

# %%
def build_xception_model(input_shape, num_classes):
    # Load Xception with pre-trained weights, exclude the top layer
    base_model = Xception(weights='imagenet', include_top=False, input_shape=input_shape)

    # Freeze the base model layers (feature extraction part)
    for layer in base_model.layers:
        layer.trainable = False

    # Add custom classification head
    x = GlobalAveragePooling2D()(base_model.output)  # Pooling to reduce dimensions
    x = Dense(512, activation='relu')(x)            # Fully connected layer
    x = Dropout(0.5)(x)                             # Dropout for regularization
    output = Dense(num_classes, activation='softmax')(x)  # Final classification layer

    # Create the final model
    model = Model(inputs=base_model.input, outputs=output)
    return model

# %%
def build_densenet_model(input_shape, num_classes):
    # Load DenseNet with pre-trained weights, exclude the top layer
    base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=input_shape)

    # Freeze the base model layers (feature extraction part)
    for layer in base_model.layers:
        layer.trainable = False

    # Add custom classification head
    x = GlobalAveragePooling2D()(base_model.output)  # Pooling to reduce dimensions
    x = Dense(512, activation='relu')(x)            # Fully connected layer
    x = Dropout(0.5)(x)                             # Dropout for regularization
    output = Dense(num_classes, activation='softmax')(x)  # Final classification layer

    model = Model(inputs=base_model.input, outputs=output)
    return model

# %%
# Compile and Train
input_shape = (224, 224, 3)  # Ensure images are resized to this shape
num_classes = train_gen.num_classes  # Number of classes from the training generator

# Define and initialize the models
models = {
    "ResNet": build_resnet_from_scratch(input_shape, num_classes),  # Custom implementation for ResNet
    "Xception": build_xception_model(input_shape, num_classes),
    "DenseNet": build_densenet_model(input_shape, num_classes)
}

# Dictionary to store training history for each model
history = {}

# Train each model
for name, model in models.items():
    # Compile the model
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    print(f"\nTraining {name} Model...")
    # Train the model and store the training history
    history[name] = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=10,
        verbose=1
    )

    # Save the model after training
    model.save(f'{name}_model.h5')  # Save the model to a .h5 file
    print(f"{name} Model saved as {name}_model.h5")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
#
# Training ResNet Model...
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 342s 565ms/step - accuracy: 0.8163 - loss: 4.8247 - val_accuracy: 0.8646 - val_loss: 0.5131
# Epoch 2/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 362s 553ms/step - accuracy: 0.8688 - loss: 0.4304 - val_accuracy: 0.8689 - val_loss: 0.4224
# Epoch 3/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 333s 577ms/step - accuracy: 0.8671 - loss: 0.4013 - val_accuracy: 0.8687 - val_loss: 0.3902
# Epoch 4/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 369s 553ms/step - accuracy: 0.8715 - loss: 0.3825 - val_accuracy: 0.8692 - val_loss: 0.3883
# Epoch 5/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 319s 550ms/step - accuracy: 0.8717 - loss: 0.3859 - val_accuracy: 0.8689 - val_loss: 0.3879
# Epoch 6/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 343s 586ms/step - accuracy: 0.8683 - loss: 0.3889 - val_accuracy: 0.8689 - val_loss: 0.3881
# Epoch 7/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 377s 578ms/step - accuracy: 0.8688 - loss: 0.3940 - val_accuracy: 0.8689 - val_loss: 0.3887
# Epoch 8/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 340s 588ms/step - accuracy: 0.8702 - loss: 0.3932 - val_accuracy: 0.8689 - val_loss: 0.3889
# Epoch 9/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 367s 563ms/step - accuracy: 0.8674 - loss: 0.3923 - val_accuracy: 0.8689 - val_loss: 0.3907
# Epoch 10/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 326s 565ms/step - accuracy: 0.8706 - loss: 0.3879 - val_accuracy: 0.8689 - val_loss: 0.3884
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ResNet Model saved as ResNet_model.h5
#
# Training Xception Model...
# Epoch 1/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 355s 585ms/step - accuracy: 0.8518 - loss: 0.4319 - val_accuracy: 0.8510 - val_loss: 0.4473
# Epoch 2/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 362s 569ms/step - accuracy: 0.8732 - loss: 0.3433 - val_accuracy: 0.8093 - val_loss: 0.5042
# Epoch 3/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 377s 562ms/step - accuracy: 0.8837 - loss: 0.3085 - val_accuracy: 0.7641 - val_loss: 0.6079
# Epoch 4/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 385s 567ms/step - accuracy: 0.8891 - loss: 0.2944 - val_accuracy: 0.8062 - val_loss: 0.5642
# Epoch 5/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 334s 578ms/step - accuracy: 0.8953 - loss: 0.2764 - val_accuracy: 0.7532 - val_loss: 0.6443
# Epoch 6/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 373s 560ms/step - accuracy: 0.8994 - loss: 0.2557 - val_accuracy: 0.7088 - val_loss: 0.7121
# Epoch 7/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 381s 562ms/step - accuracy: 0.9131 - loss: 0.2328 - val_accuracy: 0.7875 - val_loss: 0.6288
# Epoch 8/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 327s 566ms/step - accuracy: 0.9109 - loss: 0.2287 - val_accuracy: 0.7558 - val_loss: 0.7037
# Epoch 9/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 328s 565ms/step - accuracy: 0.9181 - loss: 0.2144 - val_accuracy: 0.8102 - val_loss: 0.7179
# Epoch 10/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 383s 567ms/step - accuracy: 0.9229 - loss: 0.1999 - val_accuracy: 0.6938 - val_loss: 0.8591
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Xception Model saved as Xception_model.h5
#
# Training DenseNet Model...
# Epoch 1/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 379s 608ms/step - accuracy: 0.8519 - loss: 0.4563 - val_accuracy: 0.8615 - val_loss: 0.4208
# Epoch 2/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 347s 575ms/step - accuracy: 0.8696 - loss: 0.3574 - val_accuracy: 0.8475 - val_loss: 0.4408
# Epoch 3/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 337s 584ms/step - accuracy: 0.8762 - loss: 0.3293 - val_accuracy: 0.7556 - val_loss: 0.5595
# Epoch 4/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 379s 580ms/step - accuracy: 0.8774 - loss: 0.3282 - val_accuracy: 0.7381 - val_loss: 0.5906
# Epoch 5/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 340s 589ms/step - accuracy: 0.8871 - loss: 0.3008 - val_accuracy: 0.7464 - val_loss: 0.6015
# Epoch 6/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 367s 562ms/step - accuracy: 0.8932 - loss: 0.2835 - val_accuracy: 0.7497 - val_loss: 0.5860
# Epoch 7/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 324s 562ms/step - accuracy: 0.8991 - loss: 0.2735 - val_accuracy: 0.7896 - val_loss: 0.5673
# Epoch 8/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 383s 565ms/step - accuracy: 0.9026 - loss: 0.2578 - val_accuracy: 0.8200 - val_loss: 0.5195
# Epoch 9/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 338s 586ms/step - accuracy: 0.9077 - loss: 0.2422 - val_accuracy: 0.7704 - val_loss: 0.5958
# Epoch 10/10
# 573/573 ━━━━━━━━━━━━━━━━━━━━ 325s 563ms/step - accuracy: 0.9097 - loss: 0.2339 - val_accuracy: 0.7023 - val_loss: 0.8123
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# DenseNet Model saved as DenseNet_model.h5

# %% [markdown]
# Evaluation metrics

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

def plot_confusion_matrix(y_true, y_pred, class_names, model_name):
    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Create display
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)

    # Plot confusion matrix
    disp.plot(cmap='viridis', xticks_rotation='vertical')
    plt.title(f'Confusion Matrix - {model_name}')
    plt.show()

# %%
def plot_roc_auc(y_true, y_score, num_classes, model_name):
    plt.figure(figsize=(10, 7))

    # One-hot encode true labels
    y_true_bin = label_binarize(y_true, classes=range(num_classes))

    # Multi-class or binary
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_score[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {i} (AUC = {roc_auc:.2f})')

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve - {model_name}')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
def evaluate_model(model, data_gen, class_names, model_name):
    # Predict labels
    y_true = data_gen.classes
    y_pred_probs = model.predict(data_gen)
    y_pred = np.argmax(y_pred_probs, axis=1)

    # Accuracy
    accuracy = np.mean(y_pred == y_true)

    # Classification Report
    print(f"Classification Report - {model_name}")
    print(classification_report(y_true, y_pred, target_names=class_names))

    # Confusion Matrix
    plot_confusion_matrix(y_true, y_pred, class_names, model_name)

    # ROC and AUC
    plot_roc_auc(y_true, y_pred_probs, len(class_names), model_name)

    return accuracy

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.models import load_model

models = {
    "ResNet": load_model('/content/ResNet_model_extracted/ResNet_model (1).h5'),
    "DenseNet": load_model('DenseNet_model.h5'),
    "Xception": load_model('Xception_model.h5')
}

# Define a function to plot the confusion matrix
def plot_confusion_matrix(y_true, y_pred, class_names, model_name):
    from sklearn.metrics import confusion_matrix
    import seaborn as sns
    import matplotlib.pyplot as plt

    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title(f'Confusion Matrix - {model_name}')
    plt.show()

# Add these metrics inside the loop
for name, model in models.items():
    print(f"Evaluating {name}...")

    # Get class names
    class_names = list(val_gen.class_indices.keys())

    y_pred = model.predict(val_gen)
    y_pred = y_pred.argmax(axis=1)
    y_true = val_gen.classes

    # Calculate metrics
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')

    print(f"{name} - Accuracy: {accuracy:.2f}, Precision: {precision:.2f}, Recall: {recall:.2f}, F1-Score: {f1:.2f}")

    # Plot confusion matrix
    plot_confusion_matrix(y_true, y_pred, class_names, name)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Evaluating ResNet...
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 75s 519ms/step
# ResNet - Accuracy: 0.87, Precision: 0.76, Recall: 0.87, F1-Score: 0.81
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Evaluating DenseNet...
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 98s 570ms/step
# DenseNet - Accuracy: 0.71, Precision: 0.77, Recall: 0.71, F1-Score: 0.74
# Evaluating Xception...
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 89s 534ms/step
# Xception - Accuracy: 0.70, Precision: 0.77, Recall: 0.70, F1-Score: 0.73

# %%
from sklearn.metrics import roc_curve, auc
import numpy as np
import matplotlib.pyplot as plt

# Assuming y_true is a 1D array of true class labels (0 or 1 for binary classification)
# y_pred_prob should be the predicted probabilities (from model.predict)

# Example for binary classification (use sigmoid output for binary)
y_pred_prob = model.predict(val_gen)  # This gives the probabilities for each sample

# Verify shapes to ensure they match
print(f"Shape of y_true: {y_true.shape}")
print(f"Shape of y_pred_prob: {y_pred_prob.shape}")

# Initialize dicts to store false positive rates, true positive rates, and AUCs
fpr, tpr, roc_auc = {}, {}, {}

# Generate ROC curve for binary classification
fpr, tpr, _ = roc_curve(y_true, y_pred_prob[:, 1])  # Use probability for the positive class (class 1)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(10, 8))
plt.plot(fpr, tpr, label=f'Class 1 (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line for reference (no discrimination)
plt.title(f'ROC Curve - {name}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='best')
plt.show()
# Out:
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 81s 560ms/step
# Shape of y_true: (4578,)
# Shape of y_pred_prob: (4578, 2)
